# %% [markdown]
# # Lab Assignment 13
#
# Find and tell an interesting story about games, players, teams, etc. using the [Lahman database](http://seanlahman.com/baseball-archive/statistics) or [Retrosheet](http://www.retrosheet.org/gamelogs/index.html) gamelogs for any season.
#
# * Connect to the database and perform a query to retrieve data
# * Perform a join between two or more tables to generate a new joined table
# * Visualize a bivariate relationship (e.g., correlation) between variables from the joined table
# * Identify some examples of missing cases from a non-inner join (left, right, outer)
#
# 4 minutes to present your findings on Friday, April 21. Scored based on novelty of findings, complexity of methods, or depth of analysis.
#
# Impress us.

# %%
import pandas as pd
import numpy as np
from datetime import datetime
# %matplotlib inline

from sqlalchemy import create_engine

user = 'student'
password = 'INFO2201'
host = 'lahman.cjuyvrfem14z.us-west-2.rds.amazonaws.com'
port = 3306
database = 'lahman2016'

# dialect[+driver]://user:password@host/dbname[?key=value..]
engine = create_engine('mysql+pymysql://{0}:{1}@{2}:{3}/{4}'.format(user,password,host,port,database))
#conn = engine.connect()

# %%
with engine.connect() as conn:
    tables = pd.read_sql_query('show tables',conn)
    
tables
# Out:
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# C:\Users\Lucas\Anaconda3\lib\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1043             wait = use_overflow and self._overflow >= self._max_overflow
# -> 1044             return self._pool.get(wait, self._timeout)
#    1045         except sqla_queue.Empty:
#
# C:\Users\Lucas\Anaconda3\lib\site-packages\sqlalchemy\util\queue.py in get(self, block, timeout)
#     144                 if self._empty():
# --> 145                     raise Empty
#     146             elif timeout is None:
#
# Empty:
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# C:\Users\Lucas\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
# ...
